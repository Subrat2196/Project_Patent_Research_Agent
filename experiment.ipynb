# %% [markdown]
# ### Setting up the environment

# %%
from dotenv import load_dotenv

# %%
load_dotenv(override=True)
# Out:
# True

# %% [markdown]
# ### Setting up the SERP api key

# %%
import os

# %%
serp_api_key = os.getenv("SERP_API_KEY")
if not serp_api_key:
    raise ValueError("SERP_API_KEY is not set in the environment variables")

# %% [markdown]
# ### Creating API endpoint using link

# %%
query = "Retrieval Augmented Grammer in Production"
url = f"https://serpapi.com/search?engine=google_patents&q={query}&api_key={serp_api_key}"

# %% [markdown]
# ### Client library(request library) for hitting the Serp API Endpoint using url

# %%
import requests
response=requests.get(url)
if response.status_code == 200:
    data=response.json()
    print(data)
else:
    print("Failed with status", response.status_code)
# Out:
# {'search_metadata': {'id': '6852bbd4fd81c8a297cecaaa', 'status': 'Success', 'json_endpoint': 'https://serpapi.com/searches/e2fe27e7e12c4db7/6852bbd4fd81c8a297cecaaa.json', 'created_at': '2025-06-18 13:15:00 UTC', 'processed_at': '2025-06-18 13:15:00 UTC', 'google_patents_url': 'https://patents.google.com/xhr/query?url=q%3DRetrieval%2BAugmented%2BGrammer%2Bin%2BProduction', 'raw_html_file': 'https://serpapi.com/searches/e2fe27e7e12c4db7/6852bbd4fd81c8a297cecaaa.html', 'prettify_html_file': 'https://serpapi.com/searches/e2fe27e7e12c4db7/6852bbd4fd81c8a297cecaaa.prettify', 'total_time_taken': 1.55}, 'search_parameters': {'engine': 'google_patents', 'q': 'Retrieval Augmented Grammer in Production'}, 'search_information': {'total_results': 11546, 'total_pages': 100, 'page_number': 1}, 'organic_results': [{'position': 1, 'rank': 0, 'patent_id': 'patent/US8566115B2/en', 'patent_link': 'https://patents.google.com/patent/US8566115B2/en', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_patents_details&patent_id=patent%2FUS8566115B2%2Fen', 'title': 'Syndicating surgical data in a healthcare environment', 'snippet': "Disclosed herein are systems and methods for syndication and management of structured and unstructured data to assist institutional healthcare delivery, healthcare providers' practices, healthcare providers' group practices, collaborative academic research and decision making in healthcare, …", 'priority_date': '2005-02-01', 'filing_date': '2009-02-26', 'grant_date': '2013-10-22', 'publication_date': '2013-10-22', 'inventor': 'James F. Moore', 'assignee': 'Newsilike Media Group, Inc.', 'publication_number': 'US8566115B2', 'language': 'en', 'thumbnail': 'https://patentimages.storage.googleapis.com/ee/b4/c8/56e6a3e7e81aef/US08566115-20131022-D00000.png', 'pdf': 'https://patentimages.storage.googleapis.com/d1/e5/19/8f79f8ce28c3d7/US8566115.pdf', 'figures': [{'thumbnail': 'https://patentimages.storage.googleapis.com/72/1f/77/ad64064c7bd1f9/US08566115-20131022-D00000.png', 'full': 'https://patentimages.storage.googleapis.com/76/63/c8/9fded816d24e65/US08566115-20131022-D00000.png'}, {'thumbnail': 'https://patentimages.storage.googleapis.com/f2/9a/7a/05fdba9b933cc2/US08566115-20131022-D00001.png', 'full': 'https://patentimages.storage.googleapis.com/84/15/0d/79362981a4fe9f/US08566115-20131022-D00001.png'}, {'thumbnail': 'https://patentimages.storage.googleapis.com/89/4f/98/b75d037a481f29/US08566115-20131022-D00002.png', 'full': 'https://patentimages.storage.googleapis.com/55/eb/ad/8abd58fb8d179a/US08566115-20131022-D00002.png'}, {'thumbnail': 'https://patentimages.storage.googleapis.com/48/ad/e9/fe1c8f4cfe6870/US08566115-20131022-D00003.png', 'full': 'https://patentimages.storage.googleapis.com/61/75/1b/b9e44bb5d21d7d/US08566115-20131022-D00003.png'}, {'thumbnail': 'https://patentimages.storage.googleapis.com/2f/74/c1/2b1339c97052b6/US08566115-20131022-D00004.png', 'full': 'https://patentimages.storage.googleapis.com/3c/fb/11/ab9a22497b46b5/US08566115-20131022-D00004.png'}, {'thumbnail': 'https://patentimages.storage.googleapis.com/f3/c2/1e/7c3b0694a983e3/US08566115-20131022-D00005.png', 'full': 'https://patentimages.storage.googleapis.com/e9/14/24/3083753823b462/US08566115-20131022-D00005.png'}, {'thumbnail': 'https://patentimages.storage.googleapis.com/6e/d5/ed/7b30d75478c18a/US08566115-20131022-D00006.png', 'full': 'https://patentimages.storage.googleapis.com/58/47/1d/6a5d8b95db4ddf/US08566115-20131022-D00006.png'}, {'thumbnail': 'https://patentimages.storage.googleapis.com/93/e8/0f/654eb7f21f57e7/US08566115-20131022-D00007.png', 'full': 'https://patentimages.storage.googleapis.com/56/7c/0f/bc3012031cc9d4/US08566115-20131022-D00007.png'}, {'thumbnail': 'https://patentimages.storage.googleapis.com/dd/a8/67/4ac8ee6aa01684/US08566115-20131022-D00008.png', 'full': 'https://patentimages.storage.googleapis.com/06/68/79/3758d0741f36a4/US08566115-20131022-D00008.png'}, {'thumbnail': 'https://patentimages.storage.googleapis ...

# %% [markdown]
# ### To enable a pretty/clean print we use pprint()

# %%
from pprint import pprint

# %%
import requests
response=requests.get(url)
if response.status_code == 200:
    data=response.json()
    pprint(data)
else:
    print("Failed with status", response.status_code)
# Out:
# {'organic_results': [{'assignee': 'Newsilike Media Group, Inc.',
#                       'country_status': {'US': 'ACTIVE'},
#                       'figures': [{'full': 'https://patentimages.storage.googleapis.com/76/63/c8/9fded816d24e65/US08566115-20131022-D00000.png',
#                                    'thumbnail': 'https://patentimages.storage.googleapis.com/72/1f/77/ad64064c7bd1f9/US08566115-20131022-D00000.png'},
#                                   {'full': 'https://patentimages.storage.googleapis.com/84/15/0d/79362981a4fe9f/US08566115-20131022-D00001.png',
#                                    'thumbnail': 'https://patentimages.storage.googleapis.com/f2/9a/7a/05fdba9b933cc2/US08566115-20131022-D00001.png'},
#                                   {'full': 'https://patentimages.storage.googleapis.com/55/eb/ad/8abd58fb8d179a/US08566115-20131022-D00002.png',
#                                    'thumbnail': 'https://patentimages.storage.googleapis.com/89/4f/98/b75d037a481f29/US08566115-20131022-D00002.png'},
#                                   {'full': 'https://patentimages.storage.googleapis.com/61/75/1b/b9e44bb5d21d7d/US08566115-20131022-D00003.png',
#                                    'thumbnail': 'https://patentimages.storage.googleapis.com/48/ad/e9/fe1c8f4cfe6870/US08566115-20131022-D00003.png'},
#                                   {'full': 'https://patentimages.storage.googleapis.com/3c/fb/11/ab9a22497b46b5/US08566115-20131022-D00004.png',
#                                    'thumbnail': 'https://patentimages.storage.googleapis.com/2f/74/c1/2b1339c97052b6/US08566115-20131022-D00004.png'},
#                                   {'full': 'https://patentimages.storage.googleapis.com/e9/14/24/3083753823b462/US08566115-20131022-D00005.png',
#                                    'thumbnail': 'https://patentimages.storage.googleapis.com/f3/c2/1e/7c3b0694a983e3/US08566115-20131022-D00005.png'},
#                                   {'full': 'https://patentimages.storage.googleapis.com/58/47/1d/6a5d8b95db4ddf/US08566115-20131022-D00006.png',
#                                    'thumbnail': 'https://patentimages.storage.googleapis.com/6e/d5/ed/7b30d75478c18a/US08566115-20131022-D00006.png'},
#                                   {'full': 'https://patentimages.storage.googleapis.com/56/7c/0f/bc3012031cc9d4/US08566115-20131022-D00007.png',
#                                    'thumbnail': 'https://patentimages.storage.googleapis.com
png',
#                                    'thumbnail': 'https://patentimages.storage.googleapis.com/9e/de/25/1737497be48d50/US08566115-20131022-D00030.png'},
#                                   {'full': 'https://patentimages.storage.googleapis.com/14/db/89/8c08b5b7ac1253/US08566115-20131022-D00031.png',
#                                    'thumbnail': 'https://patentimages.storage.googleapis.com/a2/61/42/782b4c65a637ec/US08566115-20131022-D00031.png'},
#                                   {'full': 'https://patentimages.storage.googleapis.com/b5/4a/e1/cf21fee0ddf5e4/US08566115-20131022-D00032.png',
#                                    'thumbnail': 'https://patentimages.storage.googleapis.com/e5/9e/9e/252c9a184ed00b/US08566115-20131022-D00032.png'},
#                                   {'full': 'https://patentimages.storage.googleapis.com/c4/fe/42/485540464431c2/US08566115-20131022-D00033.png',
#                                    'thumbnail': 'https://patentimages.storage.googleapis.com/ca/b1/a7/8573148d275043/US08566115-20131022-D00033.png'},
#                                   {'full': 'https://patentimages.storage.googleapis.com/bf/a8/30/eb72e0b58d2571/US08566115-20131022-D00034.png',
#                                    'thumbnail': 'https://patentimages.storage.googleapis.com/e8/58/69/278223cf83772e/US08566115-20131022-D00034.png'}],
#                       'filing_date': '2009-02-26',
#                       'grant_date': '2013-10-22',
#                       'inventor': 'James F. Moore',
#                       'language': 'en',
#                       'patent_id': 'patent/US8566115B2/en',
#                       'patent_link': 'https://patents.google.com/patent/US8566115B2/en',
#                       'pdf': 'https://patentimages.storage.googleapis.com/d1/e5/19/8f79f8ce28c3d7/US8566115.pdf',
#                       'position': 1,
#                       'priority_date': '2005-02-01',
#                       'publication_date': '2013-10-22',
#                       'publication_number': 'US8566115B2',
#                       'rank': 0,
#                       'serpapi_link': 'https://serpapi.com/search.json?engine=google_patents_details&patent_id=patent%2FUS8566115B2%2Fen',
#                       'snippet': 'Disclosed herein are systems and methods for '
#                                  'syndication and management of structured and '
#                                  'unstructured data to assist institutional '
#                                  "healthcare delivery, healthcare providers' "
#                                  "practices, healthcare providers' group "
#                                  'practices, collaborative academic research '
#                                  'and decision making in healthcare, …',
#                       'thumbnail': 'https://patentimages.storage.googleapis.com/ee/b4/c8/56e6a3e7e81aef/US08566115-20131022-D00000.png',
#                       'title': 'Syndicating surgical data in a healthcare '
#                                'environment'},
#                      {'assignee': 'Dennis Alan Van Dusen',
#                       'country_status': {'US': 'ACTIVE'},
#                       'figures': [{'full': 'https://patentimages.storage.googleapis.com/88/9c/34/cf56ac55850d30/US20230418876A1-20231228-D00000.png',
#                                    'thumbnail': 'https://patentimages.storage.googleapis.com/9a/7d/42/9c949538bf1ede/US20230418876A1-20231228-D00000.png'},
#                                   {'full': 'https://patentimages.storage.googleapis.com/80/52/e0/9a42090916094e/US20230418876A1-20231228-D00001.png',
#                                    'thumbnail': 'https://patentimages.storage.googleapis.com/54/21/2d/114016f7e2cd22/US20230418876A1-20231228-D00001.png'},
#                                   {'full': 'https://patentimages.storage.googleapis.com/87/bf/47/7567c4dad2b836/US20230418876A1-20231228-D00002.png',
#                                    'thumbnail': 'https://patentimages.storage.googleapis.com/c9/e0/00/0b6b9effed5e7a/US20230418876A1-20231228-D00002.png'},
#                                   {'full': 'https://patentimages.storage.googleapis.com/b1/00/4f/a335079390c1e2/US20230418876A1-20231228-D00003.png',
#                                    'thumbnail': 'https://patentimages.storage.googleapis.com/b6/e5/b5/f05b81d5cc5d9b/US20230418876A1-20231228-D00003.png'},
#                                   {'full': 'https://patentimages.storage.googleapis.com/ed/a3/18/9d4038edba4a6d/US20230418876A1-20231228-D00004.png',
#                                    'thumbnail': 'https://patentimages.storage.googleapis.com/eb/03/32/3d66b770457ef4/US20230418876A1-20231228-D00004.png'},
#                                   {'full': 'https://patentimages.storage.googleapis.com/e1/51/fb/25a604f48c2a2e/US20230418876A1-20231228-D00005.png',
#                                    'thumbnail': 'https://patentimages.storage.googleapis.com/a8/58/d7/4338667abc7ab9/US20230418876A1-20231228-D00005.png'}],
#                       'filing_date': '2023-09-08',
#                       'inventor': 'Dennis Alan Van Dusen',
#                       'language': 'en',
#                       'patent_id': 'patent/US20230418876A1/en',
#                       'patent_link': 'https://patents.google.com/patent/US20230418876A1/en',
#                       'pdf': 'https://patentimages.storage.googleapis.com/be/63/cd/f6cba52cf5931d/US20230418876A1.pdf',
#                       'position': 2,
#                       'priority_date': '2012-08-29',
#                       'publication_date': '2023-12-28',
#                       'publication_number': 'US20230418876A1',
#                       'rank': 1,
#                       'serpapi_link': 'https://serpapi.com/search.json?engine=google_patents_details&patent_id=patent%2FU
png',
#                                    'thumbnail': 'https://patentimages.storage.googleapis.com/53/0c/d3/86c0aacd7aa8ec/US20190247650A1-20190815-D00002.png'},
#                                   {'full': 'https://patentimages.storage.googleapis.com/f6/86/c7/440e0210183adf/US20190247650A1-20190815-D00003.png',
#                                    'thumbnail': 'https://patentimages.storage.googleapis.com/6b/a4/e8/b2e19b2718eb2f/US20190247650A1-20190815-D00003.png'},
#                                   {'full': 'https://patentimages.storage.googleapis.com/9f/51/9e/53a440f0ea5baf/US20190247650A1-20190815-D00004.png',
#                                    'thumbnail': 'https://patentimages.storage.googleapis.com/6d/5d/5a/40f8293c225bea/US20190247650A1-20190815-D00004.png'},
#                                   {'full': 'https://patentimages.storage.googleapis.com/10/88/ce/52fbc9d483af44/US20190247650A1-20190815-D00005.png',
#                                    'thumbnail': 'https://patentimages.storage.googleapis.com/47/40/51/3f3dc6cd53b75c/US20190247650A1-20190815-D00005.png'},
#                                   {'full': 'https://patentimages.storage.googleapis.com/4f/30/5e/3129b2635a687d/US20190247650A1-20190815-D00006.png',
#                                    'thumbnail': 'https://patentimages.storage.googleapis.com/c8/05/41/28c7ab53099216/US20190247650A1-20190815-D00006.png'},
#                                   {'full': 'https://patentimages.storage.googleapis.com/5a/af/09/2892bd476d407f/US20190247650A1-20190815-D00007.png',
#                                    'thumbnail': 'https://patentimages.storage.googleapis.com/3b/ce/c3/70351c6c11ff3e/US20190247650A1-20190815-D00007.png'},
#                                   {'full': 'https://patentimages.storage.googleapis.com/c0/47/74/bb8c11f409e9f0/US20190247650A1-20190815-D00008.png',
#                                    'thumbnail': 'https://patentimages.storage.googleapis.com/c5/64/f7/8d227ff8c335b7/US20190247650A1-20190815-D00008.png'},
#                                   {'full': 'https://patentimages.storage.googleapis.com/63/1e/3b/23bb7ae0793c68/US20190247650A1-20190815-D00009.png',
#                                    'thumbnail': 'https://patentimages.storage.googleapis.com/c3/b0/ad/bd258c0eb84961/US20190247650A1-20190815-D00009.png'}],
#                       'filing_date': '2018-02-14',
#                       'inventor': 'Ha Tran',
#                       'language': 'en',
#                       'patent_id': 'patent/US20190247650A1/en',
#                       'patent_link': 'https://patents.google.com/patent/US20190247650A1/en',
# ...
#                                     {'percentage': 0.3,
#                                      'year_range': '2019-2022'},
#                                     {'percentage': 0.3,
#                                      'year_range': '2016-2019'},
#                                     {'percentage': 0.2,
#                                      'year_range': '2013-2016'},
#                                     {'percentage': 0.1,
#                                      'year_range': '2007-2010'},
#                                     {'percentage': 0.1,
#                                      'year_range': '2004-2007'}],
#                       'key': 'G05B',
#                       'percentage': 1.1},
#                      {'frequency': [{'percentage': 0.2,
#                                      'year_range': '2022-2025'},
#                                     {'percentage': 0.1,
#                                      'year_range': '2019-2022'},
#                                     {'percentage': 0.4,
#                                      'year_range': '2016-2019'},
#                                     {'percentage': 0.1,
#                                      'year_range': '2013-2016'},
#                                     {'percentage': 0.1,
#                                      'year_range': '2001-2004'},
#                                     {'percentage': 0.2,
#                                      'year_range': '1998-2001'}],
#                       'key': 'A61B',
#                       'percentage': 1.1},
#                      {'frequency': [{'percentage': 0.3,
#                                      'year_range': '2022-2025'},
#                                     {'percentage': 0.1,
#                                      'year_range': '2010-2013'},
#                                     {'percentage': 0.4,
#                                      'year_range': '2007-2010'},
#                                     {'percentage': 0.1,
#                                      'year_range': '2004-2007'}],
#                       'key': 'H03M',
#                       'percentage': 0.9},
#                      {'frequency': [{'percentage': 0.1,
#                                      'year_range': '2019-2022'},
#                                     {'percentage': 0.5,
#                                      'year_range': '2016-2019'},
#                                     {'percentage': 0.2,
#                                      'year_range': '2013-2016'},
#                                     {'percentage': 0.1,
#                                      'year_range': '2010-2013'}],
#                       'key': 'G02B',
#                       'percentage': 0.9},
#                      {'frequency': [{'percentage': 0.2,
#                                      'year_range': '2022-2025'},
#                                     {'percentage': 0.1,
#                                      'year_range': '2019-2022'},
#                                     {'percentage': 0.1,
#                                      'year_range': '2016-2019'},
#                                     {'percentage': 0.1,
#                                      'year_range': '2013-2016'},
#                                     {'percentage': 0.1,
#                                      'year_range': '2007-2010'},
#                                     {'percentage': 0.3,
#                                      'year_range': '2004-2007'}],
#                       'key': 'A61K',
#                       'percentage': 0.9},
#                      {'frequency': [{'percentage': 0.2,
#                                      'year_range': '2022-2025'},
#                                     {'percentage': 0.1,
#                                      'year_range': '2019-2022'},
#                                     {'percentage': 0.1,
#                                      'year_range': '2016-2019'},
#                                     {'percentage': 0.1,
#                                      'year_range': '2013-2016'},
#                                     {'percentage': 0.1,
#                                      'year_range': '2007-2010'},
#                                     {'percentage': 0.2,
#                                      'year_range': '2004-2007'},
#                                     {'percentage': 0.1,
#                                      'year_range': '2001-2004'}],
#                       'key': 'A61P',
#                       'percentage': 0.9}],
#              'inventor': [{'frequency': [{'percentage': 0.7,
#                                           'year_range': '2025-2028'},
#                                          {'percentage': 26.3,
#                                           'year_range': '2022-2025'},
#                                          {'percentage': 13.0,
#                                           'year_range': '2019-2022'},
#                                          {'percentage': 10.7,
#                                           'year_range': '2016-2019'},
#                                          {'percentage': 9.6,
#                                           'year_range': '2013-2016'},
#                                          {'percentage': 6.3,
#                                           'year_range': '2010-2013'},
#                                          {'percentage': 5.8,
#                                           'year_range': '2007-2010'},
#                                          {'percentage': 12.7,
#                                           'year_range': '2004-2007'},
#                                          {'percentage': 5.5,
#                                           'year_range': '2001-2004'},
#                                          {'percentage': 4.4,
#                                           'year_range': '1998-2001'},
#                                          {'percentage': 2.1,
#                                           'year_range': '1995-1998'},
#                                          {'percentage': 1.0,
#                                           'year_range': '1992-1995'},
#                                          {'percentage': 0.4,
#                                           'year_range': '1989-1992'},
#                                          {'percentage': 0.7,
#                                           'year_range': '1986-1989'},
#                                          {'percentage': 0.5,
#                                           'year_range': '1983-1986'},
#                                          {'percentage': 0.1,
#                                           'year_range': '1980-1983'},
#                                          {'percentage': 0.1,
#                                           'year_range': '1968-1971'}],
#                            'key': 'Total',
#                            'percentage': 100.0},
#                           {'frequency': [{'percentage': 0.3,
#                                           'year_range': '2016-2019'},
#                                          {'percentage': 0.5,
#                                           'year_range': '2013-2016'},
#                                          {'percentage': 1.6,
#                                           'year_range': '2010-2013'},
#                                          {'percentage': 0.1,
#                                           'year_range': '2007-2010'},
#                                          {'percentage': 0.9,
#                                           'year_range': '2004-2007'}],
#                            'key': 'Martin T. King',
#                            'percentage': 3.4},
#                           {'frequency': [{'percentage': 0.3,
#                                           'year_range': '2016-2019'},
#                                          {'percentage': 0.5,
#                                           'year_range': '2013-2016'},
#                                          {'percentage': 1.3,
#                                           'year_range': '2010-2013'},
#                                          {'percentage': 0.2,
#                                           'year_range': '2007-2010'},
#                                          {'percentage': 0.9,
#                                           'year_range': '2004-2007'}],
#                            'key': 'Dale L. Grover',
#                            'percentage': 3.2},
#                           {'frequency': [{'percentage': 0.3,
#                                           'year_range': '2016-2019'},
#                                          {'percentage': 0.5,
#                                           'year_range': '2013-2016'},
#                                          {'percentage': 1.2,
#                                           'year_range': '2010-2013'},
#                                          {'percentage': 0.2,
#                                           'year_range': '2007-2010'},
#                                          {'percentage': 0.9,
#                                           'year_range': '2004-2007'}],
#                            'key': 'Clifford A. Kushler',
#                            'percentage': 3.1},
#                           {'frequency': [{'percentage': 0.3,
#                                           'year_range': '2016-2019'},
#                                          {'percentage': 0.4,
#                                           'year_range': '2013-2016'},
#                                          {'percentage': 1.3,
#                                           'year_range': '2010-2013'},
#                                          {'percentage': 0.1,
#                                           'year_range': '2007-2010'},
#                                          {'percentage': 0.4,
#                                           'year_range': '2004-2007'}],
#                            'key': 'James Q. Stafford-Fraser',
#                            'percentage': 2.5},
#                           {'frequency': [{'percentage': 0.1,
#                                           'year_range': '2013-2016'},
#                                          {'percentage': 0.1,
#                                           'year_range': '2010-2013'},
#                                          {'percentage': 0.1,
#                                           'year_range': '2007-2010'},
#                                          {'percentage': 2.1,
#                                           'year_range': '2004-2007'}],
#                            'key': 'Jonathan J. Hull',
#                            'percentage': 2.4},
#                           {'frequency': [{'percentage': 0.1,
#                                           'year_range': '2013-2016'},
#                                          {'percentage': 2.0,
#                                           'year_range': '2004-2007'}],
#                            'key': 'Berna Erol',
#                            'percentage': 2.1},
#                           {'frequency': [{'percentage': 0.1,
#                                           'year_range': '2013-2016'},
#                                          {'percentage': 0.1,
#                                           'year_range': '2010-2013'},
#                                          {'percentage': 1.8,
#                                           'year_range': '2004-2007'}],
#                            'key': 'Jamey Graham',
#                            'percentage': 2.0},
#                           {'frequency': [{'percentage': 0.1,
#                                           'year_range': '2013-2016'},
#                                          {'percentage': 0.1,
#                                           'year_range': '2010-2013'},
#                                          {'percentage': 0.1,
#                                           'year_range': '2007-2010'},
#                                          {'percentage': 1.5,
#                                           'year_range': '2004-2007'}],
#                            'key': 'Peter E. Hart',
#                            'percentage': 1.8},
#                           {'frequency': [{'percentage': 0.1,
#                                           'year_range': '2013-2016'},
#                                          {'percentage': 0.1,
#                                           'year_range': '2010-2013'},
#                                          {'percentage': 1.5,
#                                           'year_range': '2004-2007'}],
#                            'key': 'Kurt Piersol',
#                            'percentage': 1.7},
#                           {'frequency': [{'percentage': 0.2,
#                                           'year_range': '2013-2016'},
#                                          {'percentage': 0.2,
#                                           'year_range': '2010-2013'},
#                                          {'percentage': 0.2,
#                                           'year_range': '2007-2010'},
#                                          {'percentage': 0.9,
#                                           'year_range': '2004-2007'}],
#                            'key': 'Paul Albrecht',
#                            'percentage': 1.5},
#                           {'frequency': [{'percentage': 0.1,
#                                           'year_range': '2013-2016'},
#                                          {'percentage': 1.3,
#                                           'year_range': '2004-2007'}],
#                            'key': 'Dar-Shyang Lee',
#                            'percentage': 1.4},
#                           {'frequency': [{'percentage': 0.2,
#                                           'year_range': '2013-2016'},
#                                          {'percentage': 0.1,
#                                           'year_range': '2010-2013'},
#                                          {'percentage': 0.2,
#                                           'year_range': '2007-2010'},
#                                          {'percentage': 0.9,
#                                           'year_range': '2004-2007'}],
#                            'key': 'Lucy Gibson',
#                            'percentage': 1.4},
#                           {'frequency': [{'percentage': 0.2,
#                                           'year_range': '2013-2016'},
#                                          {'percentage': 0.1,
#                                           'year_range': '2010-2013'},
#                                          {'percentage': 0.2,
#                                           'year_range': '2007-2010'},
#                                          {'percentage': 0.8,
#                                           'year_range': '2004-2007'}],
#                            'key': 'Raymond C. Kurzweil',
#                            'percentage': 1.3},
#                           {'frequency': [{'percentage': 1.2,
#                                           'year_range': '2022-2025'}],
#                            'key': 'Barbara Sue Smith',
#                            'percentage': 1.2},
#                           {'frequency': [{'percentage': 1.2,
#                                           'year_range': '2022-2025'}],
#                            'key': 'Thanh Long Duong',
#                            'percentage': 1.2},
#                           {'frequency': [{'percentage': 1.2,
#                                           'year_range': '2022-2025'}],
#                            'key': 'Daniel J. Sullivan',
#                            'percentage': 1.2},
#                           {'frequency': [{'percentage': 1.1,
#                                           'year_range': '2022-2025'}],
#                            'key': 'Cong Duy Vu Hoang',
#                            'percentage': 1.1},
#                           {'frequency': [{'percentage': 1.1,
#                                           'year_range': '2022-2025'}],
#                            'key': 'Gioacchino Tangari',
#                            'percentage': 1.1},
#                           {'frequency': [{'percentage': 1.0,
#                                           'year_range': '2022-2025'}],
#                            'key': 'William Tunstall-Pedoe',
#                            'percentage': 1.0}]}}

# %% [markdown]
# ### We saw the output of the response, we can see that the organic result field gives a lot of details , therefore we will extract it and save it in a json file|

# %%
import json
response=requests.get(url)
if response.status_code == 200:
    data = response.json() # Parses JSON response into Python dictionary
    patents = data.get("organic_results",[]) # Safely extracts 'organic_results' list or returns empty list

    with open("files/patents.json","w") as file:
            json.dump(patents,file,indent=4)

# %% [markdown]
# ### Now we will get the specific patent information which we got inside organic results

# %% [markdown]
# ### Getting the individual Patent Results

# %%
patent_url = "https://serpapi.com/search.json?engine=google_patents_details&patent_id=patent%2FUS8566115B2%2Fen&api_key=" + serp_api_key
patents_response = requests.get(patent_url)
if patents_response.status_code == 200:
    patent_data = patents_response.json()
    with open("files/patents_specific_response.json","w") as file:
            json.dump(patent_data,file,indent=4) # Converts Python object to a JSON string and writes to a file

# %%
patent_data.keys()
# Out:
# dict_keys(['search_metadata', 'search_parameters', 'title', 'type', 'pdf', 'publication_number', 'country', 'prior_art_keywords', 'prior_art_date', 'application_number', 'inventors', 'assignees', 'priority_date', 'filing_date', 'publication_date', 'worldwide_applications', 'events', 'external_links', 'images', 'classifications', 'abstract', 'description_link', 'claims', 'child_applications', 'parent_applications', 'priority_applications', 'applications_claiming_priority', 'family_id', 'patent_citations', 'non_patent_citations', 'cited_by', 'similar_documents', 'legal_events', 'concepts'])

# %%
patent_data.get("abstract","")
# Out:
# "Disclosed herein are systems and methods for syndication and management of structured and unstructured data to assist institutional healthcare delivery, healthcare providers' practices, healthcare providers' group practices, collaborative academic research and decision making in healthcare, including through the utilization of medical devices and healthcare pools."
